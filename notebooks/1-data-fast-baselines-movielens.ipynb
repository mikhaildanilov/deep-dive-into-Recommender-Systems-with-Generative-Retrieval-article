# %%
# !pip install gin-config polars einops tqdm -q
# !git clone -b movielens_branch https://github.com/mikhaildanilov/deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article.git
# %cd deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article
# !mkdir -p dataset/ml-1m/raw
# !wget -q https://files.grouplens.org/datasets/movielens/ml-1m.zip
# !unzip -q ml-1m.zip
# !mv ml-1m/*.dat dataset/ml-1m/raw/
# Out:
# Cloning into 'deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 310 (delta 38), reused 20 (delta 5), pack-reused 219 (from 1)
# Receiving objects: 100% (310/310), 60.87 MiB | 1.99 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# /content/deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article

# %%
# !python -m baselines.run_config config/baselines/ease_ml1m.gin
# Out:
# [run_config] loaded config/baselines/ease_ml1m.gin
# [run_baseline] model=ease dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# [EASE] dataset=ml-1m split=beauty users=6040 items=3416
# [EASE] reg=250.0
# [EASE] VAL : recall@5=0.7654, ndcg@5=0.7638, coverage@5=0.1833, recall@10=0.7682, ndcg@10=0.7647, coverage@10=0.2523, recall@50=0.7867, ndcg@50=0.7686, coverage@50=0.4895, recall@100=0.8044, ndcg@100=0.7715, coverage@100=0.7090
# [EASE] TEST: recall@5=0.2107, ndcg@5=0.2043, coverage@5=0.2342, recall@10=0.2238, ndcg@10=0.2086, coverage@10=0.3141, recall@50=0.2944, ndcg@50=0.2235, coverage@50=0.5451, recall@100=0.3581, ndcg@100=0.2338, coverage@100=0.8121

# %%
# !python -m baselines.run_config config/baselines/mf_bpr_ml1m.gin
# Out:
# [run_config] loaded config/baselines/mf_bpr_ml1m.gin
# [run_baseline] model=mf_bpr dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# [MF-BPR] epoch   5/50 loss=0.1559 val: recall@5=0.0219, ndcg@5=0.0134, coverage@5=0.2491, recall@10=0.0386, ndcg@10=0.0187, coverage@10=0.3504, recall@50=0.1343, ndcg@50=0.0391, coverage@50=0.6604, recall@100=0.2163, ndcg@100=0.0523, coverage@100=0.7965
# [MF-BPR] epoch  10/50 loss=0.1358 val: recall@5=0.0223, ndcg@5=0.0138, coverage@5=0.2810, recall@10=0.0392, ndcg@10=0.0192, coverage@10=0.4011, recall@50=0.1342, ndcg@50=0.0394, coverage@50=0.7131, recall@100=0.2128, ndcg@100=0.0521, coverage@100=0.8238
# [MF-BPR] epoch  15/50 loss=0.1314 val: recall@5=0.0224, ndcg@5=0.0138, coverage@5=0.3033, recall@10=0.0388, ndcg@10=0.0190, coverage@10=0.4315, recall@50=0.1346, ndcg@50=0.0394, coverage@50=0.7362, recall@100=0.2129, ndcg@100=0.0521, coverage@100=0.8428
# ...

# %%
# !sed -i 's/device = "cpu"/device = "cuda"/' config/baselines/sasrec_ml1m.gin
# !python -m baselines.run_config config/baselines/sasrec_ml1m.gin
# Out:
# [run_config] loaded config/baselines/sasrec_ml1m.gin
# [run_baseline] model=sasrec dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# 100% 43/43 [00:01<00:00, 23.10it/s]
# 100% 43/43 [00:01<00:00, 38.94it/s]
# 100% 43/43 [00:01<00:00, 38.74it/s]
# 100% 43/43 [00:01<00:00, 38.78it/s]
# 100% 43/43 [00:01<00:00, 38.87it/s]
# 100% 43/43 [00:01<00:00, 38.96it/s]
# 100% 43/43 [00:01<00:00, 38.96it/s]
# 100% 43/43 [00:01<00:00, 38.79it/s]
# 100% 43/43 [00:01<00:00, 38.75it/s]
# 100% 43/43 [00:01<00:00, 38.96it/s]
# [SASRec] epoch  10/100 loss=5.6779 val: recall@5=0.1891, ndcg@5=0.1270, coverage@5=0.6484, recall@10=0.2790, ndcg@10=0.1559, coverage@10=0.7143, recall@50=0.5664, ndcg@50=0.2192, coverage@50=0.8691, recall@100=0.6924, ndcg@100=0.2397, coverage@100=0.9309
# 100% 43/43 [00:01<00:00, 38.49it/s]
# 100% 43/43 [00:01<00:00, 38.53it/s]
# 100% 43/43 [00:01<00:00, 38.78it/s]
# 100% 43/43 [00:01<00:00, 38.63it/s]
# 100% 43/43 [00:01<00:00, 38.57it/s]
# ...

# %%
# !sed -i 's/device = "cpu"/device = "cuda"/' config/baselines/bert4rec_ml1m.gin
# !python -m baselines.run_config config/baselines/bert4rec_ml1m.gin
# Out:
# [run_config] loaded config/baselines/bert4rec_ml1m.gin
# [run_baseline] model=bert4rec dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# 100% 43/43 [00:01<00:00, 23.05it/s]
# 100% 43/43 [00:01<00:00, 27.73it/s]
# 100% 43/43 [00:01<00:00, 27.84it/s]
# 100% 43/43 [00:01<00:00, 27.74it/s]
# 100% 43/43 [00:01<00:00, 27.69it/s]
# 100% 43/43 [00:01<00:00, 27.68it/s]
# 100% 43/43 [00:01<00:00, 27.49it/s]
# 100% 43/43 [00:01<00:00, 27.59it/s]
# 100% 43/43 [00:01<00:00, 27.74it/s]
# 100% 43/43 [00:01<00:00, 27.83it/s]
# [BERT4Rec] epoch  10/100 loss=6.4573 val: recall@5=0.0801, ndcg@5=0.0502, coverage@5=0.2957, recall@10=0.1363, ndcg@10=0.0682, coverage@10=0.3694, recall@50=0.3747, ndcg@50=0.1197, coverage@50=0.6069, recall@100=0.5154, ndcg@100=0.1425, coverage@100=0.7169
# 100% 43/43 [00:01<00:00, 27.48it/s]
# 100% 43/43 [00:01<00:00, 27.62it/s]
# 100% 43/43 [00:01<00:00, 27.65it/s]
# 100% 43/43 [00:01<00:00, 27.68it/s]
# 100% 43/43 [00:01<00:00, 27.77it/s]
# ...

# %%
print(228)
# !sed -i 's/seed = 42/seed = 228/' config/baselines/mf_bpr_ml1m.gin
# !python -m baselines.run_config config/baselines/mf_bpr_ml1m.gin

print(1337)
# !sed -i 's/seed = 228/seed = 1337/' config/baselines/mf_bpr_ml1m.gin
# !python -m baselines.run_config config/baselines/mf_bpr_ml1m.gin
# Out:
# 228
# [run_config] loaded config/baselines/mf_bpr_ml1m.gin
# [run_baseline] model=mf_bpr dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# [MF-BPR] epoch   5/50 loss=0.1560 val: recall@5=0.0207, ndcg@5=0.0129, coverage@5=0.2327, recall@10=0.0382, ndcg@10=0.0185, coverage@10=0.3355, recall@50=0.1338, ndcg@50=0.0390, coverage@50=0.6461, recall@100=0.2151, ndcg@100=0.0521, coverage@100=0.7664
# [MF-BPR] epoch  10/50 loss=0.1364 val: recall@5=0.0220, ndcg@5=0.0134, coverage@5=0.2886, recall@10=0.0400, ndcg@10=0.0191, coverage@10=0.4019, recall@50=0.1347, ndcg@50=0.0393, coverage@50=0.7102, recall@100=0.2154, ndcg@100=0.0523, coverage@100=0.8311
# [MF-BPR] epoch  15/50 loss=0.1307 val: recall@5=0.0223, ndcg@5=0.0133, coverage@5=0.3021, recall@10=0.0405, ndcg@10=0.0191, coverage@10=0.4283, recall@50=0.1357, ndcg@50=0.0395, coverage@50=0.7374, recall@100=0.2145, ndcg@100=0.0522, coverage@100=0.8469
# ...

# %%
print(228)
# !sed -i 's/seed = 42/seed = 228/' config/baselines/sasrec_ml1m.gin
# !python -m baselines.run_config config/baselines/sasrec_ml1m.gin

print(1337)
# !sed -i 's/seed = 228/seed = 1337/' config/baselines/sasrec_ml1m.gin
# !python -m baselines.run_config config/baselines/sasrec_ml1m.gin
# Out:
# 228
# [run_config] loaded config/baselines/sasrec_ml1m.gin
# [run_baseline] model=sasrec dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# 100% 43/43 [00:01<00:00, 30.23it/s]
# 100% 43/43 [00:01<00:00, 39.19it/s]
# 100% 43/43 [00:01<00:00, 39.11it/s]
# 100% 43/43 [00:01<00:00, 39.18it/s]
# 100% 43/43 [00:01<00:00, 39.02it/s]
# 100% 43/43 [00:01<00:00, 38.75it/s]
# 100% 43/43 [00:01<00:00, 38.97it/s]
# 100% 43/43 [00:01<00:00, 39.00it/s]
# 100% 43/43 [00:01<00:00, 39.04it/s]
# 100% 43/43 [00:01<00:00, 39.10it/s]
# [SASRec] epoch  10/100 loss=5.6814 val: recall@5=0.1882, ndcg@5=0.1256, coverage@5=0.6417, recall@10=0.2771, ndcg@10=0.1542, coverage@10=0.7122, recall@50=0.5598, ndcg@50=0.2164, coverage@50=0.8627, recall@100=0.6849, ndcg@100=0.2368, coverage@100=0.9180
# 100% 43/43 [00:01<00:00, 38.98it/s]
# 100% 43/43 [00:01<00:00, 38.80it/s]
# 100% 43/43 [00:01<00:00, 38.74it/s]
# 100% 43/43 [00:01<00:00, 38.87it/s]
# 100% 43/43 [00:01<00:00, 38.85it/s]
# ...

# %%
print(228)
# !sed -i 's/seed = 42/seed = 228/' config/baselines/bert4rec_ml1m.gin
# !python -m baselines.run_config config/baselines/bert4rec_ml1m.gin

print(1337)
# !sed -i 's/seed = 228/seed = 1337/' config/baselines/bert4rec_ml1m.gin
# !python -m baselines.run_config config/baselines/bert4rec_ml1m.gin
# Out:
# 228
# [run_config] loaded config/baselines/bert4rec_ml1m.gin
# [run_baseline] model=bert4rec dataset=ml-1m split=beauty users=6040 items=3416 ks=[5, 10, 50, 100]
# 100% 43/43 [00:01<00:00, 23.18it/s]
# 100% 43/43 [00:01<00:00, 28.10it/s]
# 100% 43/43 [00:01<00:00, 28.13it/s]
# 100% 43/43 [00:01<00:00, 28.04it/s]
# 100% 43/43 [00:01<00:00, 27.98it/s]
# 100% 43/43 [00:01<00:00, 27.44it/s]
# 100% 43/43 [00:01<00:00, 28.01it/s]
# 100% 43/43 [00:01<00:00, 28.00it/s]
# 100% 43/43 [00:01<00:00, 27.95it/s]
# 100% 43/43 [00:01<00:00, 28.07it/s]
# [BERT4Rec] epoch  10/100 loss=6.4753 val: recall@5=0.0837, ndcg@5=0.0527, coverage@5=0.2968, recall@10=0.1418, ndcg@10=0.0713, coverage@10=0.3788, recall@50=0.3790, ndcg@50=0.1228, coverage@50=0.6235, recall@100=0.5174, ndcg@100=0.1453, coverage@100=0.7292
# 100% 43/43 [00:01<00:00, 27.83it/s]
# 100% 43/43 [00:01<00:00, 27.93it/s]
# 100% 43/43 [00:01<00:00, 28.00it/s]
# 100% 43/43 [00:01<00:00, 27.88it/s]
# 100% 43/43 [00:01<00:00, 27.91it/s]
# ...
