# %%
# !pip install gin-config polars einops tqdm -q
# !git clone https://github.com/mikhaildanilov/deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article.git
# %cd deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article

# %%
# !pip install gdown -q
# !gdown 1qGxgmx7G_WB7JE4Cn_bEcZ_o_NAJLE3G -O P5_data.zip
# !unzip -q P5_data.zip
# !mkdir -p dataset/amazon/raw
# !mv data/* dataset/amazon/raw/
# !ls dataset/amazon/raw/

# %%
import sys; sys.path.insert(0, '.')

# %%
# Accelerator: None

# !python -m baselines.ease --split beauty

# %%
# Accelerator: None

print("seed 42:")
# !python -m baselines.mf_bpr --split beauty --epochs 50 --seed 42
print("seed 228:")
# !python -m baselines.mf_bpr --split beauty --epochs 50 --seed 228
print("seed 1337:")
# !python -m baselines.mf_bpr --split beauty --epochs 50 --seed 1337

# %%
# Accelerator: GPU T4 x2

print("seed 42:")
# !python -m baselines.sasrec --split beauty --epochs 100 --device cuda --seed 42
print("seed 228:")
# !python -m baselines.sasrec --split beauty --epochs 100 --device cuda --seed 228
print("seed 1337:")
# !python -m baselines.sasrec --split beauty --epochs 100 --device cuda --seed 1337

# %%
# Accelerator: GPU T4 x2

print("seed 42:")
# !python -m baselines.bert4rec --split beauty --epochs 100 --device cuda --seed 42
print("seed 228:")
# !python -m baselines.bert4rec --split beauty --epochs 100 --device cuda --seed 228
print("seed 1337:")
# !python -m baselines.bert4rec --split beauty --epochs 100 --device cuda --seed 1337
