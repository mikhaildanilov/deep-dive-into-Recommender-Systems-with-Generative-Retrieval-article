# %%
# !pip install gin-config polars einops tqdm gdown -q
# !git clone -b global_temp_split https://github.com/mikhaildanilov/deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article.git
# %cd deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article
# !gdown 1qGxgmx7G_WB7JE4Cn_bEcZ_o_NAJLE3G -O P5_data.zip
# !unzip -q P5_data.zip && mkdir -p dataset/amazon/raw && mv data/* dataset/amazon/raw/
# !git checkout -- data/

# %%
# !gdown 169UMnUANphCYOpYVGRGpRuIVvI9shbEN -O beauty_data.zip
# !rm -r dataset/amazon/raw/beauty
# !unzip -q beauty_data.zip
# !cp -r beauty dataset/amazon/raw/beauty

# %%
# RQ-3: число уровней

# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --n-layers 2
# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --n-layers 3
# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --n-layers 4

# %%
# RQ-4: размер кодбука

# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --codebook-size 64
# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --codebook-size 256
# !python -m baselines.tiger --split beauty --id-method random --epochs 5000 --codebook-size 1024
