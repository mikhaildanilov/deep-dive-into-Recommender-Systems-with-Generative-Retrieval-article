# %%
# !pip install gin-config polars einops tqdm sentence-transformers==2.7.0 -q
# !git clone -b movielens_branch https://github.com/mikhaildanilov/deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article.git
# %cd deep-dive-into-Recommender-Systems-with-Generative-Retrieval-article
# !mkdir -p dataset/ml-1m/raw
# !wget -q https://files.grouplens.org/datasets/movielens/ml-1m.zip
# !unzip -q ml-1m.zip
# !mv ml-1m/*.dat dataset/ml-1m/raw/

# !sed -i 's/device = "gpu"/device = "cuda"/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/t5_d_model = 128/t5_d_model = 64/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/t5_num_heads = 6/t5_num_heads = 2/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/t5_num_layers = 4/t5_num_layers = 2/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/t5_d_ff = 1024/t5_d_ff = 256/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/max_len = 200/max_len = 50/' config/baselines/tiger_lsh_ml1m.gin
# !sed -i 's/batch_size = 256/batch_size = 64/' config/baselines/tiger_lsh_ml1m.gin

# %%
# !python -m baselines.run_config config/baselines/tiger_lsh_ml1m.gin
